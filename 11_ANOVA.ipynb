# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('automobile.csv')

# %% [markdown]
# <h2 id="ANOVA(Analysis of Varience)">ANOVA(Analysis of Varience)</h2>
#
#
#
# ANOVA is a statistical technique used to compare the means of two or more groups(or statistical comparison of groups)
# Eg:- Average Price of Different vehicle makes.
# - **F-test Score** :- The F-test calculates the ratio of variation between the groups's mean over the variation within each of the sample groups
# - **P-Value** :- The p-value shows whether the obtained result is statistically significant.(Confidence Degree)

# %%
df_anova=df[['make','price']]
grouped_anova=df_anova.groupby(['make'])

# %%
anova_results_1 = stats.f_oneway(grouped_anova.get_group('honda')['price'],grouped_anova.get_group('subaru')['price'])
# Out:
# C:\Users\dubey\AppData\Local\Temp\ipykernel_13044\1698800205.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   anova_results_1 = stats.f_oneway(grouped_anova.get_group('honda')['price'],grouped_anova.get_group('subaru')['price'])

# %%
print(anova_results_1)
# Out:
# F_onewayResult(statistic=np.float64(0.19744030127462606), pvalue=np.float64(0.6609478240622193))

# %% [markdown]
# The prices between Hondas and Subarus are not significantly different, as the F-test
# score is less than 1 and p-value is larger than 0.05.

# %%
anova_results_2 = stats.f_oneway(grouped_anova.get_group('honda')['price'],grouped_anova.get_group('jaguar')['price'])
# Out:
# C:\Users\dubey\AppData\Local\Temp\ipykernel_13044\1445250941.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   anova_results_2 = stats.f_oneway(grouped_anova.get_group('honda')['price'],grouped_anova.get_group('jaguar')['price'])

# %%
anova_results_2
# Out:
# F_onewayResult(statistic=np.float64(400.925870564337), pvalue=np.float64(1.0586193512077865e-11))

# %% [markdown]
# The prices between Hondas and Jaguars are significantly different, since the F-score
# is very large (F = 401) and the p-value is larger than 0.05.
# All in all, we can say that there is a strong correlation between a categorical variable
# and other variables, if the ANOVA test gives us a large F-test value and a small p-value.

# %% [markdown]
# <h1 id="correlation">correlation</h1>
#
#
# between different variables.
# Correlation is a statistical metric for measuring to what extent different variables are interdependent.
# In other words, when we look at two variables over time, if one variable changes, how does
# this effect change in the other variable?

# %% [markdown]
# This time we’ll visualize these two variables using a scatterplot and an added linear line
# called a “regression line”, which indicates the relationship between the two.

# %%
sns.regplot(x='engine-size',y = 'price',data=df)
plt.ylim(0,)
# Out:
# (0.0, 53208.4792124879)

# %% [markdown]
# In this example, you can see that the straight line through the data points is very steep,
# which shows that there is a positive linear relationship between the two variables.
# With increase in values of engine size, values of price go up as well and the slope of the
# line is positive, so there is a positive correlation between “engine-size” and “price”.

# %% [markdown]
# As another example, now let’s look at the relationship between highway-miles per gallon
# to see its impact on the car “price”.

# %%
sns.regplot(x='highway-mpg', y='price', data=df)
plt.ylim(0,)
# Out:
# (0.0, 48183.27349906545)

# %% [markdown]
# As we can see in this plot, when highway-mpg value goes up, the value of price goes down,
# therefore there is a negative linear relationship between highway-mpg and price.
# Although this relationship is negative, the slope of the line is steep which means that
# the highway miles per gallon is still a good predictor of price.
# These two variables are said to have a negative correlation

# %% [markdown]
# <h2 id="Correlation-Statistics">Correlation-Statistics</h2>
# <h3>Pearson correlation </h3>
#
# - measure the strength of the correlation between two features
#     - correlation coeeficient
#     - p-value
#
# - **Correlation coefficient**
#     - Close to +1 : large positive relationship
#     - Close to -1 : large negative relationship
#     - Close to 0 : No relationship
#
# - **p-value**
#     - The p-value will tell us how certain we are about the correlation that we calculated.
#     - P-value < 0.001 Strong certanity in the result
#     - P-value < 0.05 Moderate certanity in the result
#     - P-value < 0.1 weak certanity in the result
#     - P-value > 0.1 No certanity in the result

# %% [markdown]
# **Strong correlation**
#    - Correlation coefficient close to 1 or -1
#    - P-values less than 0.001

# %%
from IPython.display import Image, display
display(Image(filename='D:/my own/correlation.png'))

# %% [markdown]
# The following plot shows data with different correlation values.

# %%
pearson_coef , p_value = stats.pearsonr(df['horsepower'], df['price'])

# %%
print(pearson_coef, p_value)
# Out:
# nan nan
