# %%
import pandas as pd
import numpy as np

# %%
path="D:/my own/automobile.csv"

# %%
df = pd.read_csv(path )

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %% [markdown]
# **Data Preprocessing**
# process of converting or mapping data from one “raw” form into another also known as data cleaning or wrangling
#
# you can add a value to each entry of a column.
# To add 1 to each “symbolling” entry, use df["symboling"]=df["symboling"]+1.

# %%
df["symboling"]=df["symboling"]+1

# %% [markdown]
# **Dealing With Missing Values in Python**
#
# When no data value is stored for a feature for a particular observation, we say this
# feature has a “missing value”.
# Usually, missing value in dataset appears as “?”, “N/A”, 0, "NaN" or just a blank cell.
#
# *methods to deal the missing value*
# - drop the variable or whole data entry
# - replace it with an average(mean) of column
# - replace it with the frequency (mode) of that column

# %% [markdown]
# **Remove the missing data**
# To remove data that contains missing values, pandas library has a built-in method called
# **‘dropna’**.
# Essentially, with the dropna method, you can choose to drop rows or columns that contain
# missing values, like NaN. So you’ll need to specify “axis=0” to drop the rows, or “axis=1” to drop the columns that contain the missing values.
#
# It can simply be done in one line of code using dataframe.dropna().
# Setting the argument “inplace” to “true” allows the modification to be done on the
# dataset directly.
# “Inplace=True” just writes the result back into the dataframe.

# %%
df.head(5)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          4                NaN  alfa-romero       gas        std
# 1          4                NaN  alfa-romero       gas        std
# 2          2                NaN  alfa-romero       gas        std
# 3          3              164.0         audi       gas        std
# 4          3              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# now we have to delete the NaN values in normalized losses

# %%
df.dropna(subset=["normalized-losses"], axis=0)
# Out:
#      symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 3            3              164.0   audi       gas        std         four
# 4            3              164.0   audi       gas        std         four
# 6            2              158.0   audi       gas        std         four
# 8            2              158.0   audi       gas      turbo         four
# 9            3              192.0    bmw       gas        std          two
# ..         ...                ...    ...       ...        ...          ...
# 196          0               95.0  volvo       gas        std         four
# 197          0               95.0  volvo       gas      turbo         four
# 198          0               95.0  volvo       gas        std         four
# 199          0               95.0  volvo    diesel      turbo         four
# 200          0               95.0  volvo       gas      turbo         four
#
# ...

# %%
#df.dropna(subset=["normalized-losses"], axis=0, inplace = True)

# %% [markdown]
# this code will update the data frame

# %% [markdown]
# **Replacing the missing values**
#
# To replace missing values like NaNs with actual values, pandas library has a built in method
# called ‘replace’, which can be used to fill in the missing values with the newly calculated values.
# "dataframe.replace(missing value, new value)"
#
# assume that we want to replace the missing values of the variable ‘normalized-losses’ by the mean value of the variable.

# %%
mean=df["normalized-losses"].mean()
print(mean)
# Out:
# 122.0

# %%
df.head(10)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          4                NaN  alfa-romero       gas        std
# 1          4                NaN  alfa-romero       gas        std
# 2          2                NaN  alfa-romero       gas        std
# 3          3              164.0         audi       gas        std
# 4          3              164.0         audi       gas        std
# 5          3                NaN         audi       gas        std
# 6          2              158.0         audi       gas        std
# 7          2                NaN         audi       gas        std
# 8          2              158.0         audi       gas      turbo
# 9          3              192.0          bmw       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# ...

# %%
df["normalized-losses"].replace(np.nan , mean)
# Out:
# 0      122.0
# 1      122.0
# 2      122.0
# 3      164.0
# 4      164.0
#        ...
# 196     95.0
# 197     95.0
# 198     95.0
# 199     95.0
# 200     95.0
# Name: normalized-losses, Length: 201, dtype: float64
